# %%
# Create a list of 5 fruits and print the third fruit.
fruits = ['apple', 'banana', 'cherry', 'date', 'elderberry']
print(fruits[4])
# Out:
# elderberry

# %%
#Create a dictionary with keys: name, age. Print the value of age.
people = {'name': 'Alice', 'age': 30}
print(people['age'])
# Out:
# 30

# %%
#Define a tuple with three numbers. Try modifying it. What happens?
numbers = (1,2,3)

numbers[0]= 10
# i get an error becouse tupples are imutable
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 4
#       1 #Define a tuple with three numbers. Try modifying it. What happens?
#       2 numbers = (1,2,3)
# ----> 4 numbers[0]= 10
#
# TypeError: 'tuple' object does not support item assignment

# %%
#Create a set from a list with duplicate values.
fruits = ['apple', 'banana', 'cherry', 'date', 'elderberry', 'apple', 'banana' ]
set_fruits = set(fruits)
print(set_fruits)
# Out:
# {'banana', 'elderberry', 'date', 'cherry', 'apple'}
