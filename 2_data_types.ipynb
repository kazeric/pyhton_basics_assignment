# %%
#Print the type of 42, 3.14, and 'hello'.
print(type(42))
print(type(3.14))
print(type("hello"))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>

# %%
number_str = '100'
number_int = int(number_str)
print(type(number_int))
print(number_int)
# Out:
# <class 'int'>
# 100

# %%
x = 3
y = 20.2

result = x+y
print(result)
print(type(result))

# the resulting type is a float
# Out:
# 23.2
# <class 'float'>

# %%
x = '100'
y= 2

result = x*y
print(result)
print(type(result))

#the string is concantinated and repeats by the number if the number is an in 
# if the number is a float though an error is raised
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 4
#       1 x = '100'
#       2 y= 2.2
# ----> 4 result = x*y
#       5 print(result)
#       6 print(type(result))
#
# TypeError: can't multiply sequence by non-int of type 'float'

# %% [markdown]
# # Challenge
